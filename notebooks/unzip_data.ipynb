# %%
import sys
from pathlib import Path

# %%
ROOT_DIR = Path.cwd().parent
ROOT_DIR
# Out:
# PosixPath('/home/chiendoan/Code_Module6/TRANSFORMER_FOR_IMAGE_TIMESERIES_DATA')

# %%
SRC_DIR = ROOT_DIR/'src'

# %%
# Thêm đường dẫn ở vị trí thư mục gốc vào sys để tìm kiếm 
sys.path.extend([str(ROOT_DIR), str(SRC_DIR)])

# %%
from src.process_dataraw.unzip_file import UnzipFile

# %%
UnzipFile??
# Out:
# Signature: UnzipFile(path: str = None, output: str = None) -> dict
# Docstring: <no docstring>
# Source:
# def UnzipFile(path: str = None, output: str = None) -> dict:
#     import zipfile
#     """
#     Input:
#     path: đường dẫn file zip cần giải nén
#     output: thư mục output sẽ chứa file sau khi giải nén
#     """
#
#     return_result = {
#         "code": 200,
#         "message": "Success!"
#     }
#     try:
#         with zipfile.ZipFile(path, 'r') as zip_ref:
#             zip_ref.extractall(output)
#             file_names = zip_ref.namelist()
#             return_result["file_names"] = file_names
#     except Exception as e:
#         return_result["code"] = 500
#         return_result["message"] = f"Error: {e}"
#
#     return return_result
# File:      ~/Code_Module6/TRANSFORMER_FOR_IMAGE_TIMESERIES_DATA/src/process_dataraw/unzip_file.py
# Type:      function

# %%
DATA_DIR = ROOT_DIR/'data'

# %%
IMAGE_RAW_DIR = ROOT_DIR/'data_raw'/'images-001.zip'

# %%
CAPTION_RAW_DIR = ROOT_DIR/'data_raw'/'drive-download-20260910T040016Z-1-002.zip'

# %% [markdown]
# # Unzip image

# %%
UnzipFile(path=str(IMAGE_RAW_DIR), output=str(DATA_DIR))
# Out:
# {'code': 200,
#  'message': 'Success!',
#  'file_names': ['images/',
#   'images/00000008928.jpg',
#   'images/00000006905.jpg',
#   'images/00000012970.jpg',
#   'images/00000008525.png',
#   'images/00000004874.jpg',
#   'images/00000008096.jpg',
#   'images/00000009388.jpg',
#   'images/00000010801.jpg',
#   'images/00000008082.jpg',
#   'images/00000001918.jpg',
#   'images/00000010815.jpg',
#   'images/00000001515.png',
#   'images/00000004860.jpg',
#   'images/00000012964.jpg',
#   'images/00000003869.jpg',
#   'images/00000006911.jpg',
#   'images/00000003699.jpg',
#   'images/00000003841.jpg',
#   'images/00000012794.jpg',
#   'images/00000002587.jpg',
#   'images/00000008914.jpg',
#   'images/00000010183.jpg',
#   'images/00000000390.jpg',
#   'images/00000006939.jpg',
#   'images/00000001930.jpg',
#   'images/00000007399.jpg',
#   'images/00000006087.jpg',
#   'images/00000004848.jpg',
#   'images/00000004690.jpg',
#   'images/00000001924.jpg',
# ...

# %% [markdown]
# # Unzip caption

# %%
UnzipFile(path=str(CAPTION_RAW_DIR), output=str(DATA_DIR/'captions'))
# Out:
# {'code': 200,
#  'message': 'Success!',
#  'file_names': ['uit-openviic-annotation-test.json',
#   'uit-openviic-annotation-dev.json',
#   'uit-openviic-annotation-train.json']}
