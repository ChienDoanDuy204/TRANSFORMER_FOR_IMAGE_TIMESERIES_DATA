# %%
from pathlib import Path
import sys

# %%
ROOT_DIR = Path.cwd().parent
ROOT_DIR
# Out:
# PosixPath('/home/chiendoan/Code_Module6/TRANSFORMER_FOR_IMAGE_TIMESERIES_DATA')

# %%
sys.path.extend([str(ROOT_DIR)])

# %%
from src.custom_dataset.organize_data import *

# %%
IMAGE_DIR = ROOT_DIR/'data'/'images'
CAPTION_DIR = ROOT_DIR/'data'/'captions'

# %%
dataset = ImageCaptionDataSet(img_dir=IMAGE_DIR, caption_dir=CAPTION_DIR)

# %%
dataset[0]
# Out:
# (tensor([[[0.2196, 0.2235, 0.2353,  ..., 0.3804, 0.5608, 0.8471],
#           [0.1490, 0.2118, 0.2431,  ..., 0.3529, 0.4196, 0.6196],
#           [0.1725, 0.1490, 0.2275,  ..., 0.3333, 0.3608, 0.4275],
#           ...,
#           [0.2392, 0.2980, 0.3255,  ..., 0.0824, 0.1020, 0.2235],
#           [0.3098, 0.3294, 0.3333,  ..., 0.1020, 0.1059, 0.1216],
#           [0.3294, 0.3451, 0.3490,  ..., 0.1098, 0.1020, 0.0902]],
#
#          [[0.3137, 0.3216, 0.3373,  ..., 0.4039, 0.5255, 0.8039],
#           [0.2275, 0.3098, 0.3451,  ..., 0.3843, 0.4275, 0.5725],
#           [0.2588, 0.2314, 0.3216,  ..., 0.3647, 0.3882, 0.4353],
#           ...,
#           [0.2275, 0.2784, 0.3020,  ..., 0.0784, 0.0941, 0.2000],
#           [0.2941, 0.3098, 0.3176,  ..., 0.0941, 0.0941, 0.1059],
#           [0.3137, 0.3255, 0.3333,  ..., 0.1020, 0.0980, 0.0784]],
#
#          [[0.4039, 0.4314, 0.4510,  ..., 0.4863, 0.5216, 0.6902],
#           [0.2980, 0.4039, 0.4549,  ..., 0.4745, 0.4980, 0.5176],
#           [0.3373, 0.3098, 0.4196,  ..., 0.4471, 0.4784, 0.5020],
#           ...,
#           [0.2275, 0.2745, 0.2980,  ..., 0.0431, 0.0510, 0.1059],
#           [0.2941, 0.3098, 0.3176,  ..., 0.0471, 0.0431, 0.0745],
#           [0.3098, 0.3294, 0.3412,  ..., 0.0549, 0.0588, 0.0471]]]),
#  'một con phố vắng_vẻ có một tán cây lớn che ngang')
